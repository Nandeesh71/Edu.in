# %% [markdown]
# 2. Tokenization, Stopword Removal, Stemming and Lemmatization
#
# Aim:
# To write a Python Program to perform preprocessing tasks using NLTK.
#
# Algorithm/Procedure:
# 1. Start
# 2. Import Libraries:
# a. nltk
# b. word_tokenize, sent_tokenize from nltk.tokenize
# c. stopwords from nltk.corpus
# d. PorterStemmer, WordNetLemmatizer from nltk.stem
# 3. Download Required NLTK Resources:
# a. punkt (tokenizers)
# b. punkt_tab (tokenizer update)
# c. stopwords (common stopwords)
# d. wordnet (lexical database for lemmatization)
# e. omw-1.4 (wordnet data)
# 4. Input Text:
# a. Store the text in a variable text.
# 5. Sentence Tokenization:
# a. Use sent_tokenize(text) to split the text into sentences.
# 6. Word Tokenization:
# a. Use word_tokenize(text) to split the text into individual words.
# 7. Stopword Removal:
# a. Get the set of English stopwords using stopwords.words('english').
# b. Remove words from the token list that appear in the stopword set.
# 8. Stemming:
# a. Initialize PorterStemmer().
# b. Apply the stemmer to each word in the filtered list.
# 9. Lemmatization:
# a. Initialize WordNetLemmatizer().
# 10. Apply the lemmatizer to each word in the filtered list.
# 11. Display Results:
# 12. Print sentence tokens ,word tokens ,words after stopword removal ,stemmed words and lemmatized words
# 13. Stop
#
# Output:
#
# Sentence Tokens:
# ['\nNatural Language Processing is a branch of Artificial Intelligence.', 'It enables computers to understand human language and process text efficiently.']
# Word Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'enables', 'computers', 'to', 'understand', 'human', 'language', 'and', 'process', 'text', 'efficiently', '.']
# Words After Stopword Removal:
# ['Natural', 'Language', 'Processing', 'branch', 'Artificial', 'Intelligence', '.', 'enables', 'computers', 'understand', 'human', 'language', 'process', 'text', 'efficiently', '.']
# Stemmed Words:
# ['natur', 'languag', 'process', 'branch', 'artifici', 'intellig', '.', 'enabl', 'comput', 'understand', 'human', 'languag', 'process', 'text', 'effici', '.']
# Lemmatized Words:
# ['Natural', 'Language', 'Processing', 'branch', 'Artificial', 'Intelligence', '.', 'enables', 'computer', 'understand', 'human', 'language', 'process', 'text', 'efficiently', '.']
#
# Result:
# Thus, the program was implemented successfully and the output was verified.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
text = """
Natural Language Processing is a branch of Artificial Intelligence.
It enables computers to understand human language and process text efficiently.
"""

sentences = sent_tokenize(text)
sentences

words = word_tokenize(text)
words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  '.',
#  'It',
#  'enables',
#  'computers',
#  'to',
#  'understand',
#  'human',
#  'language',
#  'and',
#  'process',
#  'text',
#  'efficiently',
#  '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
filtered_words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'branch',
#  'Artificial',
#  'Intelligence',
#  '.',
#  'enables',
#  'computers',
#  'understand',
#  'human',
#  'language',
#  'process',
#  'text',
#  'efficiently',
#  '.']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
stemmed_words
# Out:
# ['natur',
#  'languag',
#  'process',
#  'branch',
#  'artifici',
#  'intellig',
#  '.',
#  'enabl',
#  'comput',
#  'understand',
#  'human',
#  'languag',
#  'process',
#  'text',
#  'effici',
#  '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

lemmatized_words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'branch',
#  'Artificial',
#  'Intelligence',
#  '.',
#  'enables',
#  'computer',
#  'understand',
#  'human',
#  'language',
#  'process',
#  'text',
#  'efficiently',
#  '.']
